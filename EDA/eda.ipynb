# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"D:\AI Lab\python codes\EDA\os_worldwide.csv")
df
# Out:
#         Date  Windows  Android    iOS  OS X  Unknown  Linux  Series 40  \
# 0    2009-01    94.80     0.00   0.24  3.66     0.27   0.64        0.0
# 1    2009-02    94.74     0.01   0.25  3.73     0.22   0.61        0.0
# 2    2009-03    94.48     0.02   0.32  3.84     0.25   0.64        0.0
# 3    2009-04    94.32     0.02   0.36  3.89     0.26   0.66        0.0
# 4    2009-05    94.44     0.02   0.32  3.72     0.32   0.64        0.0
# ..       ...      ...      ...    ...   ...      ...    ...        ...
# 175  2023-08    30.15    39.16  16.47  8.78     1.84   1.40        0.0
# 176  2023-09    30.76    37.66  16.63  9.06     2.10   1.37        0.0
# 177  2023-10    31.23    37.34  16.51  9.22     1.78   1.34        0.0
# 178  2023-11    30.61    38.33  16.55  9.32     1.41   1.44        0.0
# 179  2023-12    29.14    41.72  17.74  6.56     1.94   1.55        0.0
#
#      SymbianOS  Samsung  ...  Nokia Unknown  Playstation  Sony Ericsson  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           180 non-null    object
#  1   Windows        180 non-null    float64
#  2   Android        180 non-null    float64
#  3   iOS            180 non-null    float64
#  4   OS X           180 non-null    float64
#  5   Unknown        180 non-null    float64
#  6   Linux          180 non-null    float64
#  7   Series 40      180 non-null    float64
#  8   SymbianOS      180 non-null    float64
#  9   Samsung        180 non-null    float64
#  10  BlackBerry OS  180 non-null    float64
#  11  Chrome OS      180 non-null    float64
#  12  Nokia Unknown  180 non-null    float64
#  13  Playstation    180 non-null    float64
#  14  Sony Ericsson  180 non-null    float64
#  15  KaiOS          180 non-null    float64
#  16  Xbox           180 non-null    float64
# ...

# %%
df.describe()
# Out:
#           Windows     Android         iOS        OS X     Unknown       Linux  \
# count  180.000000  180.000000  180.000000  180.000000  180.000000  180.000000
# mean    54.155500   24.296111   10.354167    6.095444    1.687778    0.914222
# std     23.275397   17.013412    5.727105    1.096718    1.294940    0.205421
# min     27.710000    0.000000    0.240000    3.660000    0.170000    0.610000
# 25%     35.202500    4.012500    5.357500    5.465000    0.625000    0.760000
# 50%     43.425000   31.835000   12.100000    5.995000    1.430000    0.825000
# 75%     77.547500   39.812500   14.395000    6.572500    2.472500    1.082500
# max     94.800000   44.710000   17.880000    9.320000    8.050000    1.550000
#
#         Series 40   SymbianOS     Samsung  BlackBerry OS  ...  Nokia Unknown  \
# count  180.000000  180.000000  180.000000     180.000000  ...     180.000000
# mean     0.543444    0.519556    0.297778       0.261833  ...       0.170056
# ...

# %%
df2=df.groupby('Date').mean().sort_values(by="Windows",ascending=False)
df2.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.drop(df.iloc[:,10:],inplace=True,axis=1)
df
# Out:
#         Date  Windows  Android    iOS  OS X  Unknown  Linux  Series 40  \
# 0    2009-01    94.80     0.00   0.24  3.66     0.27   0.64        0.0
# 1    2009-02    94.74     0.01   0.25  3.73     0.22   0.61        0.0
# 2    2009-03    94.48     0.02   0.32  3.84     0.25   0.64        0.0
# 3    2009-04    94.32     0.02   0.36  3.89     0.26   0.66        0.0
# 4    2009-05    94.44     0.02   0.32  3.72     0.32   0.64        0.0
# ..       ...      ...      ...    ...   ...      ...    ...        ...
# 175  2023-08    30.15    39.16  16.47  8.78     1.84   1.40        0.0
# 176  2023-09    30.76    37.66  16.63  9.06     2.10   1.37        0.0
# 177  2023-10    31.23    37.34  16.51  9.22     1.78   1.34        0.0
# 178  2023-11    30.61    38.33  16.55  9.32     1.41   1.44        0.0
# 179  2023-12    29.14    41.72  17.74  6.56     1.94   1.55        0.0
#
#      SymbianOS  Samsung
# 0         0.26     0.00
# 1         0.26     0.00
# 2         0.28     0.00
# ...

# %%
sns.heatmap(df.corr(),annot=True)
plt.rcParams['figure.figsize']=(10,9)
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')
january_data = df[df['Date'].dt.month == 1]
january_data = january_data.reset_index(drop=True)

# %%
df3=january_data.groupby('Date').mean().sort_values(by="Windows",ascending=False)
df3.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df = df.set_index(df.columns[0])


specific_date = '2023-01-01'


specific_date_data = df.loc[specific_date]


os_market_percentage = specific_date_data / specific_date_data.sum() * 100


plt.figure(figsize=(10, 6))
os_market_percentage.plot(kind='bar')
plt.xlabel('Operating System')
plt.ylabel('Market Percentage (%)')
plt.title('Market Percentage of Different Operating Systems at {}'.format(specific_date))
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8, 8))
os_market_percentage.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Market Percentage of Different Operating Systems at {}'.format(specific_date))
plt.ylabel('')  # Hide the ylabel
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(os_market_percentage)
plt.xlabel('Market Percentage (%)')
plt.ylabel('Frequency')
plt.title('Distribution of Market Percentages of Different Operating Systems at {}'.format(specific_date))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.displot(os_market_percentage, kde=True, rug=True)
plt.xlabel('Market Percentage (%)')
plt.ylabel('Density')
plt.title('Distribution of Market Percentages of Different Operating Systems at {}'.format(specific_date))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=os_market_percentage)
plt.xlabel('Operating Systems')
plt.ylabel('Market Percentage (%)')
plt.title('Distribution of Market Percentages of Different Operating Systems at {}'.format(specific_date))
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
